# %% [markdown]
# First we import the multipole_calculations module and the same name function

# %%
import multipole_calculations
from multipole_calculations.multipoles import multipole_calculations

# %% [markdown]
# Then, we introduce the values of dielectric constant for the solute and solvent region, the constant kappa and the h value, used to compute  numerically derivation of the reaction potential.

# %%
ep_in = 1.
ep_ex = 78.3
k = 0.125
h = 0.01

# %% [markdown]
# Finally, we call the multipole_calculations function, the first argument is the name of file used in the simulation, whitout the .xyz or .key extension, the second argument is the mesh filename, whitout .face or .vert extension, rest of them are the phisic constants.
# The optional arguments are:

# %% [markdown]
# maxiter: Maximum number of iterations used to calculate the induced dipole, 100 by default.

# %% [markdown]
# gmres_maxiter: Maximum number of iterations used by gmres to solve the linear system, 500 by default.

# %% [markdown]
# mu: Initial induced dipole, all 0 by default.

# %% [markdown]
# tol: Tolerance used to check the convergence of induced dipole, 1e-2 by default.

# %% [markdown]
# gmres_tol: Tolerance used by gmres, 1e-5 by default.

# %%
t_energy = multipole_calculations("examples/1pgb/1pgb", "examples/1pgb/1pgb_gs_4", ep_in, ep_ex, k, h, tol=1e-2)
# Out:
# Reading parameters from amoebapro13.prm
# /home/felipevicencio/miniconda3/envs/bempp_prod/lib/python3.8/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:318: SparseEfficiencyWarning: splu requires CSC matrix format
#   warn('splu requires CSC matrix format', SparseEfficiencyWarning)
# ------- Iteration 1 -------
# Gmres iteration 1, residual: 0.9918863531918481
# Gmres iteration 2, residual: 0.42714406706844577
# Gmres iteration 3, residual: 0.40430012084892275
# Gmres iteration 4, residual: 0.2478609108105018
# Gmres iteration 5, residual: 0.2324010291264881
# Gmres iteration 6, residual: 0.16515715793647415
# Gmres iteration 7, residual: 0.1559737526421368
# Gmres iteration 8, residual: 0.11097527560370177
# Gmres iteration 9, residual: 0.09938303168329335
# Gmres iteration 10, residual: 0.07570987319939437
# Gmres iteration 11, residual: 0.06802618073487589
# Gmres iteration 12, residual: 0.05582590634375573
# Gmres iteration 13, residual: 0.05146491588877747
# Gmres iteration 14, residual: 0.04184809702284865
# Gmres iteration 15, residual: 0.038224811131437234
# Gmres iteration 16, residual: 0.033044541561011914
# Gmres iteration 17, residual: 0.028441435137746062
# Gmres iteration 18, residual: 0.026057356403123674
# Gmres iteration 19, residual: 0.021806012084849075
# Gmres iteration 20, residual: 0.019978916613632162
# Gmres iteration 21, residual: 0.01642697410320537
# Gmres iteration 22, residual: 0.014919285596197566
# Gmres iteration 23, residual: 0.01203475438971039
# Gmres iteration 24, residual: 0.01116174234490779
# Gmres iteration 25, residual: 0.009255076216369519
# Gmres iteration 26, residual: 0.00877190810891997
# Gmres iteration 27, residual: 0.007513979553956029
# Gmres iteration 28, residual: 0.006930714339641224
# Gmres iteration 29, residual: 0.005892785216168403
# Gmres iteration 30, residual: 0.005425116531233664
# Gmres iteration 31, residual: 0.004586242808522638
# Gmres iteration 32, residual: 0.004135210143350545
# Gmres iteration 33, residual: 0.0036590837876867665
# Gmres iteration 34, residual: 0.0033252990483069833
# Gmres iteration 35, residual: 0.0029531110031790994
# Gmres iteration 36, residual: 0.002629130986234037
# Gmres iteration 37, residual: 0.0023557703806673493
# Gmres iteration 38, residual: 0.002095517293959299
# Gmres iteration 39, residual: 0.0019081908010058174
# Gmres iteration 40, residual: 0.0017249349995528656
# Gmres iteration 41, residual: 0.001587291053744262
# Gmres iteration 42, residual: 0.0014023609274595834
# Gmres iteration 43, residual: 0.0013153247963302523
# Gmres iteration 44, residual: 0.0011696127602533737
# Gmres iteration 45, residual: 0.0010932849882960536
# Gmres iteration 46, residual: 0.0009699819147772484
# Gmres iteration 47, residual: 0.0009201264050171026
# Gmres iteration 48, residual: 0.0008163888146822049
# Gmres iteration 49, residual: 0.000777424150898646
# Gmres iteration 50, residual: 0.0006854754685506254
# Gmres iteration 51, residual: 0.000661155630848786
# Gmres iteration 52, residual: 0.0006023576446333606
# Gmres iteration 53, residual: 0.0005752880087580792
# Gmres iteration 54, residual: 0.0005221463831293296
# Gmres iteration 55, residual: 0.0004953001186741859
# Gmres iteration 56, residual: 0.000447842688526573
# Gmres iteration 57, residual: 0.00042683793325018406
# Gmres iteration 58, residual: 0.00038656906847766925
# Gmres iteration 59, residual: 0.0003646279461959794
# Gmres iteration 60, residual: 0.00033502129315904843
# Gmres iteration 61, residual: 0.0003115278929277692
# Gmres iteration 62, residual: 0.0002880705758027706
# Gmres iteration 63, residual: 0.0002647980963731797
# Gmres iteration 64, residual: 0.0002490701082516284
# Gmres iteration 65, residual: 0.00022620635463323796
# Gmres iteration 66, residual: 0.00021539593039916695
# Gmres iteration 67, residual: 0.0001972979914701084
# Gmres iteration 68, residual: 0.00018806069436611234
# Gmres iteration 69, residual: 0.0001692768300863625
# Gmres iteration 70, residual: 0.0001616378075158549
# Gmres iteration 71, residual: 0.00014790497477360368
# Gmres iteration 72, residual: 0.00014233589546162905
# Gmres iteration 73, residual: 0.00012887221112501781
# Gmres iteration 74, residual: 0.0001229310196557213
# Gmres iteration 75, residual: 0.00011241479461866782
# Gmres iteration 76, residual: 0.00010669910614658148
# Gmres iteration 77, residual: 9.679382150148807e-05
# Gmres iteration 78, residual: 9.182588733339052e-05
# Gmres iteration 79, residual: 8.450755344961967e-05
# Gmres iteration 80, residual: 7.949495399812573e-05
# Gmres iteration 81, residual: 7.213468223752476e-05
# Gmres iteration 82, residual: 6.80469028904402e-05
# Gmres iteration 83, residual: 6.158348748696723e-05
# Gmres iteration 84, residual: 5.7742320708577076e-05
# Gmres iteration 85, residual: 5.332584060262104e-05
# Gmres iteration 86, residual: 4.961385135307996e-05
# Gmres iteration 87, residual: 4.567786207275749e-05
# Gmres iteration 88, residual: 4.194361533568586e-05
# Gmres iteration 89, residual: 3.865377550889632e-05
# Gmres iteration 90, residual: 3.584849709837464e-05
# Gmres iteration 91, residual: 3.358393299922678e-05
# Gmres iteration 92, residual: 3.081862089133765e-05
# Gmres iteration 93, residual: 2.9035432270819507e-05
# Gmres iteration 94, residual: 2.65237823898154e-05
# Gmres iteration 95, residual: 2.5003654198838416e-05
# Gmres iteration 96, residual: 2.2741422076634847e-05
# Gmres iteration 97, residual: 2.1275373739401188e-05
# Gmres iteration 98, residual: 1.930700316758849e-05
# Gmres iteration 99, residual: 1.8229041279445853e-05
# Gmres iteration 100, residual: 1.6664077157098268e-05
# Gmres iteration 101, residual: 1.5800755848451724e-05
# Gmres iteration 102, residual: 1.4330178170577548e-05
# Gmres iteration 103, residual: 1.3531381694629333e-05
# Gmres iteration 104, residual: 1.2442863264208165e-05
# Gmres iteration 105, residual: 1.1759978692316199e-05
# Gmres iteration 106, residual: 1.080574981753404e-05
# Gmres iteration 107, residual: 1.0110278258657467e-05
# Gmres iteration 108, residual: 9.421529566922229e-06
# Induced dipole residual: 0.04341853098930539
# ------- Iteration 2 -------
# Gmres iteration 1, residual: 0.04041296532965276
# Gmres iteration 2, residual: 0.03362330513844652
# Gmres iteration 3, residual: 0.03195112479765783
# Gmres iteration 4, residual: 0.029063909013676927
# Gmres iteration 5, residual: 0.028999039783345122
# Gmres iteration 6, residual: 0.021643571900121367
# Gmres iteration 7, residual: 0.01999457529328098
# Gmres iteration 8, residual: 0.016485467585395503
# Gmres iteration 9, residual: 0.01515436061656504
# Gmres iteration 10, residual: 0.012143109032821505
# Gmres iteration 11, residual: 0.010660133997770275
# Gmres iteration 12, residual: 0.009118137551405362
# Gmres iteration 13, residual: 0.00812330905527836
# Gmres iteration 14, residual: 0.007286130719715697
# Gmres iteration 15, residual: 0.0062158528454948105
# Gmres iteration 16, residual: 0.005612627659059609
# Gmres iteration 17, residual: 0.0048495461429614315
# Gmres iteration 18, residual: 0.004391286930150747
# Gmres iteration 19, residual: 0.0037448598482916276
# Gmres iteration 20, residual: 0.0033064074094313967
# Gmres iteration 21, residual: 0.002926516709646476
# Gmres iteration 22, residual: 0.00257971802543881
# Gmres iteration 23, residual: 0.00229968871506475
# Gmres iteration 24, residual: 0.002000819194469379
# Gmres iteration 25, residual: 0.0017543425945997226
# Gmres iteration 26, residual: 0.0015525693889013197
# Gmres iteration 27, residual: 0.0014144345609351681
# Gmres iteration 28, residual: 0.0012633970612429886
# Gmres iteration 29, residual: 0.0011244517633711049
# Gmres iteration 30, residual: 0.0010014917139150046
# Gmres iteration 31, residual: 0.0008668998435426787
# Gmres iteration 32, residual: 0.0007602344734114194
# Gmres iteration 33, residual: 0.0006542009017601428
# Gmres iteration 34, residual: 0.0005823317226529527
# Gmres iteration 35, residual: 0.000511917633473904
# Gmres iteration 36, residual: 0.00045765488171672924
# Gmres iteration 37, residual: 0.0004093071802192196
# Gmres iteration 38, residual: 0.00036526253693114564
# Gmres iteration 39, residual: 0.00033011683096048817
# Gmres iteration 40, residual: 0.0002978303296008815
# Gmres iteration 41, residual: 0.00028069551298143193
# Gmres iteration 42, residual: 0.0002518143413876705
# Gmres iteration 43, residual: 0.00023317093862148608
# Gmres iteration 44, residual: 0.00021277446775491333
# Gmres iteration 45, residual: 0.00019603782471383505
# Gmres iteration 46, residual: 0.0001777792408055838
# Gmres iteration 47, residual: 0.00016444763519166174
# Gmres iteration 48, residual: 0.00014991491771589594
# Gmres iteration 49, residual: 0.0001409610017842735
# Gmres iteration 50, residual: 0.00012674411114495685
# Gmres iteration 51, residual: 0.00012139808761152495
# Gmres iteration 52, residual: 0.00010929250210015327
# Gmres iteration 53, residual: 0.00010433870784826992
# Gmres iteration 54, residual: 9.39612847968081e-05
# Gmres iteration 55, residual: 8.877118073693899e-05
# Gmres iteration 56, residual: 7.992519089621589e-05
# Gmres iteration 57, residual: 7.484751309225778e-05
# Gmres iteration 58, residual: 6.858222161253296e-05
# Gmres iteration 59, residual: 6.426226973608986e-05
# Gmres iteration 60, residual: 5.888106091452268e-05
# Gmres iteration 61, residual: 5.504826973908489e-05
# Gmres iteration 62, residual: 5.0195490686860586e-05
# Gmres iteration 63, residual: 4.705945498158057e-05
# Gmres iteration 64, residual: 4.3232735845530784e-05
# Gmres iteration 65, residual: 4.0380457750663034e-05
# Gmres iteration 66, residual: 3.718019061841657e-05
# Gmres iteration 67, residual: 3.423107111836189e-05
# Gmres iteration 68, residual: 3.207908279152186e-05
# Gmres iteration 69, residual: 2.9659940494716433e-05
# Gmres iteration 70, residual: 2.7832454700832807e-05
# Gmres iteration 71, residual: 2.528864224943758e-05
# Gmres iteration 72, residual: 2.3786317193580106e-05
# Gmres iteration 73, residual: 2.17068652283168e-05
# Gmres iteration 74, residual: 2.0244467949752445e-05
# Gmres iteration 75, residual: 1.8663318306918167e-05
# Gmres iteration 76, residual: 1.7576533011025235e-05
# Gmres iteration 77, residual: 1.6121407922910718e-05
# Gmres iteration 78, residual: 1.5264202440495866e-05
# Gmres iteration 79, residual: 1.3959870970592052e-05
# Gmres iteration 80, residual: 1.3191408074156737e-05
# Gmres iteration 81, residual: 1.1968435017464382e-05
# Gmres iteration 82, residual: 1.1244133322007296e-05
# Gmres iteration 83, residual: 1.029355961035106e-05
# Gmres iteration 84, residual: 9.568052909013378e-06
# Induced dipole residual: 0.017819966489028262
# ------- Iteration 3 -------
# Gmres iteration 1, residual: 0.013414893850128843
# Gmres iteration 2, residual: 0.01094081636134231
# Gmres iteration 3, residual: 0.0100961923968301
# Gmres iteration 4, residual: 0.008767206438655984
# Gmres iteration 5, residual: 0.00846396765297809
# Gmres iteration 6, residual: 0.0070811222204833
# Gmres iteration 7, residual: 0.0065059513091737095
# Gmres iteration 8, residual: 0.005312515545506825
# Gmres iteration 9, residual: 0.004779285160548956
# Gmres iteration 10, residual: 0.004030805485474503
# Gmres iteration 11, residual: 0.0035339901984976973
# Gmres iteration 12, residual: 0.003053544112375272
# Gmres iteration 13, residual: 0.0027644058246809695
# Gmres iteration 14, residual: 0.002404868150026559
# Gmres iteration 15, residual: 0.0020970951385318915
# Gmres iteration 16, residual: 0.0019236553760568825
# Gmres iteration 17, residual: 0.0015943990565807154
# Gmres iteration 18, residual: 0.001455648388422279
# Gmres iteration 19, residual: 0.0012186957339086
# Gmres iteration 20, residual: 0.00111329746700114
# Gmres iteration 21, residual: 0.0009418445596780892
# Gmres iteration 22, residual: 0.0008427954805047753
# Gmres iteration 23, residual: 0.0007512734407874467
# Gmres iteration 24, residual: 0.0006482973388095215
# Gmres iteration 25, residual: 0.0005758513917519705
# Gmres iteration 26, residual: 0.0005082990577044357
# Gmres iteration 27, residual: 0.00045972943908388517
# Gmres iteration 28, residual: 0.0004098581329254994
# Gmres iteration 29, residual: 0.000370439774439941
# Gmres iteration 30, residual: 0.00032931325726175424
# Gmres iteration 31, residual: 0.0002949488881771138
# Gmres iteration 32, residual: 0.0002570347863348003
# Gmres iteration 33, residual: 0.00022982721307130566
# Gmres iteration 34, residual: 0.0002022246864828572
# Gmres iteration 35, residual: 0.00018327205495426616
# Gmres iteration 36, residual: 0.0001606327221567611
# Gmres iteration 37, residual: 0.0001478864812537304
# Gmres iteration 38, residual: 0.00013146088272918393
# Gmres iteration 39, residual: 0.00012125421221933777
# Gmres iteration 40, residual: 0.00010651972121721375
# Gmres iteration 41, residual: 9.888144091863265e-05
# Gmres iteration 42, residual: 8.83499249770174e-05
# Gmres iteration 43, residual: 8.14654079796165e-05
# Gmres iteration 44, residual: 7.271529672039013e-05
# Gmres iteration 45, residual: 6.88866311166397e-05
# Gmres iteration 46, residual: 6.12146413857179e-05
# Gmres iteration 47, residual: 5.754476614258882e-05
# Gmres iteration 48, residual: 5.1760396573833626e-05
# Gmres iteration 49, residual: 4.931782670582508e-05
# Gmres iteration 50, residual: 4.470109515464022e-05
# Gmres iteration 51, residual: 4.215919329266149e-05
# Gmres iteration 52, residual: 3.8227358706296476e-05
# Gmres iteration 53, residual: 3.638710262361396e-05
# Gmres iteration 54, residual: 3.264515361249573e-05
# Gmres iteration 55, residual: 3.071426422141626e-05
# Gmres iteration 56, residual: 2.7744947596177046e-05
# Gmres iteration 57, residual: 2.596538875958917e-05
# Gmres iteration 58, residual: 2.3904195677973188e-05
# Gmres iteration 59, residual: 2.251542944237231e-05
# Gmres iteration 60, residual: 2.089112183617482e-05
# Gmres iteration 61, residual: 1.9454508699805373e-05
# Gmres iteration 62, residual: 1.8006624449145834e-05
# Gmres iteration 63, residual: 1.6425603023059742e-05
# Gmres iteration 64, residual: 1.55427094536554e-05
# Gmres iteration 65, residual: 1.4301610691434758e-05
# Gmres iteration 66, residual: 1.3599639756293519e-05
# Gmres iteration 67, residual: 1.2309902112801764e-05
# Gmres iteration 68, residual: 1.1710329102164906e-05
# Gmres iteration 69, residual: 1.0694500550107881e-05
# Gmres iteration 70, residual: 1.0136930067327845e-05
# Gmres iteration 71, residual: 9.253206086071146e-06
# The induced dipole in dissolved state has converged in 3 iterations
# Induced dipole residual in vacuum: 0.0479486268370835
# Induced dipole residual in vacuum: 0.019381059860645523
# Induced dipole residual in vacuum: 0.010725219822068434
# Induced dipole residual in vacuum: 0.005995068091471971
# 4 iterations for vacuum induced dipole to converge
# Solvent contribution: -987.1350322951573 [kcal/Mol]
# Multipoles contribution: -17576.547374204798 [kcal/Mol]
# Coulomb vacuum energy: -17711.59495660803
# These values consider the polarization energy
# Total solvation energy: -852.0874498919256 [kcal/Mol]
